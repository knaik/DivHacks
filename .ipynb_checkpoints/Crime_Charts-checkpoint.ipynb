# %%
import dask.dataframe as dd
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'

# set neat seaborn whitegrid styles for matplotlib charts
plt.style.use('seaborn')
sns.set_style('whitegrid')

# %%
# load all data into memory
crimes = pd.read_csv("Chicago_Crimes_2012_to_2017.csv", encoding = "ISO-8859-1", index_col = 'Date')
print('Crime data loaded into memory.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-412a126dacaa> in <module>
#       1 # load all data into memory
# ----> 2 crimes = pd.read_csv("Chicago_Crimes_2012_to_2017.csv", encoding = "ISO-8859-1", index_col = 'Date')
#       3 print('Crime data loaded into memory.')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1979         if kwds.get("compression") is None and encoding:
#    1980             if isinstance(src, str):
# -> 1981                 src = open(src, "rb")
#    1982                 self.handles.append(src)
#    1983
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Chicago_Crimes_2012_to_2017.csv'

# %%
# preview crimes data with Date index
crimes.head(5)
# Out:
#                         Unnamed: 0        ID Case Number                Block  \
# Date
# 05/03/2016 11:40:00 PM           3  10508693    HZ250496   013XX S SAWYER AVE
# 05/03/2016 09:40:00 PM          89  10508695    HZ250409   061XX S DREXEL AVE
# 05/03/2016 11:31:00 PM         197  10508697    HZ250503  053XX W CHICAGO AVE
# 05/03/2016 10:10:00 PM         673  10508698    HZ250424    049XX W FULTON ST
# 05/03/2016 10:00:00 PM         911  10508699    HZ250455    003XX N LOTUS AVE
#
#                         IUCR            Primary Type              Description  \
# Date
# 05/03/2016 11:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 09:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 11:31:00 PM  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 05/03/2016 10:10:00 PM  0460                 BATTERY                   SIMPLE
# 05/03/2016 10:00:00 PM  0820                   THEFT           $500 AND UNDER
#
#                        Location Description  Arrest  Domestic  ...  Ward  \
# Date                                                           ...
# 05/03/2016 11:40:00 PM            APARTMENT    True      True  ...  24.0
# 05/03/2016 09:40:00 PM            RESIDENCE   False      True  ...  20.0
# 05/03/2016 11:31:00 PM               STREET   False     False  ...  37.0
# 05/03/2016 10:10:00 PM             SIDEWALK   False     False  ...  28.0
# 05/03/2016 10:00:00 PM            RESIDENCE   False      True  ...  28.0
#
#                         Community Area  FBI Code  X Coordinate Y Coordinate  \
# Date
# 05/03/2016 11:40:00 PM            29.0       08B     1154907.0    1893681.0
# 05/03/2016 09:40:00 PM            42.0       08B     1183066.0    1864330.0
# 05/03/2016 11:31:00 PM            25.0        24     1140789.0    1904819.0
# 05/03/2016 10:10:00 PM            25.0       08B     1143223.0    1901475.0
# 05/03/2016 10:00:00 PM            25.0        06     1139890.0    1901675.0
#
#                         Year              Updated On   Latitude  Longitude  \
# Date
# 05/03/2016 11:40:00 PM  2016  05/10/2016 03:56:50 PM  41.864073 -87.706819
# 05/03/2016 09:40:00 PM  2016  05/10/2016 03:56:50 PM  41.782922 -87.604363
# 05/03/2016 11:31:00 PM  2016  05/10/2016 03:56:50 PM  41.894908 -87.758372
# 05/03/2016 10:10:00 PM  2016  05/10/2016 03:56:50 PM  41.885687 -87.749516
# 05/03/2016 10:00:00 PM  2016  05/10/2016 03:56:50 PM  41.886297 -87.761751
#
#                                              Location
# Date
# 05/03/2016 11:40:00 PM  (41.864073157, -87.706818608)
# 05/03/2016 09:40:00 PM   (41.782921527, -87.60436317)
# 05/03/2016 11:31:00 PM  (41.894908283, -87.758371958)
# 05/03/2016 10:10:00 PM  (41.885686845, -87.749515983)
# 05/03/2016 10:00:00 PM  (41.886297242, -87.761750709)
#
# [5 rows x 22 columns]

# %%
# %%time

# get crime types
crime_types = crimes[['Primary Type']]

# get crime counts by primary type
crime_type_total = crime_types.groupby('Primary Type').size()

# get arrests and domestic counts for each primary crime type
crime_type_counts = crimes[['Primary Type', 'Arrest', 'Domestic']]\
.groupby('Primary Type').sum()

# add crime type totals column
crime_type_counts['Total'] = crime_type_total

# print all crime stats (arrests, domestic, and totals)
print(crime_type_counts.sort_values(by='Total', ascending=False))
# Out:
#                                      Arrest  Domestic   Total
# Primary Type
# THEFT                               36673.0   10519.0  329460
# BATTERY                             60501.0  129130.0  263700
# CRIMINAL DAMAGE                     10165.0   15933.0  155455
# NARCOTICS                          134317.0      63.0  135240
# ASSAULT                             21348.0   23099.0   91289
# OTHER OFFENSE                       18573.0   27776.0   87874
# BURGLARY                             4463.0     636.0   83397
# DECEPTIVE PRACTICE                   8917.0     748.0   75495
# MOTOR VEHICLE THEFT                  4254.0     575.0   61138
# ROBBERY                              5460.0     857.0   57313
# CRIMINAL TRESPASS                   25927.0    1501.0   36912
# WEAPONS VIOLATION                   13746.0      57.0   17233
# PUBLIC PEACE VIOLATION               9949.0     414.0   13122
# OFFENSE INVOLVING CHILDREN           1821.0    6087.0   11398
# PROSTITUTION                         7599.0       2.0    7633
# CRIM SEXUAL ASSAULT                   809.0    1029.0    6823
# INTERFERENCE WITH PUBLIC OFFICER     5861.0      22.0    6195
# SEX OFFENSE                          1187.0     524.0    4885
# HOMICIDE                              882.0     172.0    2649
# ARSON                                 218.0      91.0    2217
# GAMBLING                             2205.0       0.0    2212
# LIQUOR LAW VIOLATION                 1912.0       3.0    1953
# KIDNAPPING                             98.0     326.0    1099
# STALKING                              142.0     376.0     828
# INTIMIDATION                          118.0      78.0     662
# OBSCENITY                             149.0      30.0     187
# NON-CRIMINAL                            7.0       1.0      93
# CONCEALED CARRY LICENSE VIOLATION      77.0       0.0      90
# PUBLIC INDECENCY                       62.0       1.0      62
# NON - CRIMINAL                          6.0       0.0      38
# OTHER NARCOTIC VIOLATION               21.0       0.0      30
# HUMAN TRAFFICKING                       4.0       1.0      28
# NON-CRIMINAL (SUBJECT SPECIFIED)        1.0       3.0       4
# Wall time: 225 ms

# %%
# plot crimes by primary type counts
all_crime_types = crime_type_counts.sort_values(by='Total', ascending=True)\
.drop(['Arrest', 'Domestic'], axis=1) # denotes column
all_crime_types.plot(kind='barh', figsize=(10,8), color='#cc0000')
plt.title('All Chicago Crimes by Type (2001-2017)')
plt.xlabel('Number of Crime reports')
plt.ylabel('Crime Type')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
